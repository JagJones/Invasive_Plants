# %%
# Here I've taken the data from the second dataframe (df2) from the main Invasive Plant Species notebook 
# and turned it into a dictionary. Again, using pandas.

import pandas as pd

# Currently stuck- Don't know how t write this so it fills in a dict that I chose the name for.
# header=None, squeeze=True

plant_dict = pd.read_csv('data/Invasive_Plants_Threat_Levels - Sheet1.csv').to_dict()

# %%
pd.set_option('display.max_rows', 164)
df = pd.DataFrame(plant_dict)

# %%
df
# Out:
#                   Scientific Name                  Common Name  Threat Level
# 0            Achyranthes japonica        Japanese chaff flower             1
# 1             Ailanthus altissima               tree-of-heaven             1
# 2              Alliaria petiolata               garlic mustard             1
# 3     Ampelopsis brevipedunculata              porcelain berry             1
# 4              Arthraxon hispidus             hairy jointgrass             1
# ..                            ...                          ...           ...
# 159   Viburnum opulus var. opulus  European highbush cranberry             4
# 160                  Vicia cracca                   bird vetch             4
# 161                  Vicia sativa                 common vetch             4
# 162  Vicia villosa subsp. Villosa                 winter vetch             4
# 163               Zelkova serrata                      zelkova             4
#
# [164 rows x 3 columns]

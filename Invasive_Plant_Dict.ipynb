# %%
# Here I've taken the data from the second dataframe (df2) from the main Invasive Plant Species notebook 
# and turned it into a dictionary. Again, using pandas.

import pandas as pd

# Currently stuck- Don't know how t write this so it fills in a dict that I chose the name for.
# header=None, squeeze=True

plant_dict = pd.read_csv('data/Invasive_Plants_Threat_Levels - Sheet1.csv').to_dict()

# %%
pd.set_option('display.max_rows', 164)

# %%
df = pd.DataFrame(plant_dict)

# %%
df
# Out:
#                                        Scientific Name  \
# 0                                 Achyranthes japonica
# 1                                  Ailanthus altissima
# 2                                   Alliaria petiolata
# 3                          Ampelopsis brevipedunculata
# 4                                   Arthraxon hispidus
# 5                                       Carduus nutans
# 6                                Celastrus orbiculatus
# 7                                      Cirsium arvense
# 8                                  Clematis terniflora
# 9                                     Conium maculatum
# 10                 Coronilla varia (=Securigera varia)
# 11                               Dioscorea polystachya
# 12                                 Elaeagnus umbellata
# 13                                     Euonymus alatus
# 14                                   Euonymus fortunei
# 15          Festuca arundinacea (=Lolium arundinaceum)
# ...
